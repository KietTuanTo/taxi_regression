# %% [markdown]
# A simple machine learning algorithm which predicts the cost of a taxi trip in NYC, using data from 2024

# %%
# Importing dependencies

import io
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import requests

import keras
# Out:
# 2024-09-01 17:35:08.215058: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-01 17:35:08.224260: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-01 17:35:08.275048: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-01 17:35:08.349083: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-01 17:35:08.411284: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-01 17:35:08.428943: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-01 17:35:08.553546: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-01 17:35:10.642175: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Create data frame containing nyc taxi data
data = pq.ParquetFile("data.parquet")
first_thousand = next(data.iter_batches(batch_size=70000))
df = pa.Table.from_batches([first_thousand]).to_pandas()

training_df = df[['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'trip_distance', 'fare_amount']]
training_df
# Out:
#       tpep_pickup_datetime tpep_dropoff_datetime  trip_distance  fare_amount
# 0      2024-01-01 00:57:55   2024-01-01 01:17:43           1.72        17.70
# 1      2024-01-01 00:03:00   2024-01-01 00:09:36           1.80        10.00
# 2      2024-01-01 00:17:06   2024-01-01 00:35:01           4.70        23.30
# 3      2024-01-01 00:36:38   2024-01-01 00:44:56           1.40        10.00
# 4      2024-01-01 00:46:51   2024-01-01 00:52:57           0.80         7.90
# ...                    ...                   ...            ...          ...
# 69995  2024-01-01 23:06:03   2024-01-01 23:28:54           5.10        25.40
# 69996  2024-01-01 23:51:07   2024-01-01 23:59:24           4.44        19.10
# 69997  2024-01-01 23:00:00   2024-01-01 23:17:31           7.99        33.10
# 69998  2024-01-01 23:03:21   2024-01-01 23:18:07           7.37        19.47
# 69999  2024-01-01 23:09:36   2024-01-01 23:24:43           8.51        33.80
#
# [70000 rows x 4 columns]

# %%
# Summary statistics of nyc taxi dataset
training_df.describe(include="all")
# Out:
#              tpep_pickup_datetime       tpep_dropoff_datetime  trip_distance  \
# count                       70000                       70000   70000.000000
# mean   2024-01-01 04:00:41.879085  2024-01-01 04:17:12.342257       4.196633
# min           2002-12-31 22:59:39         2002-12-31 23:05:41       0.000000
# 25%           2024-01-01 03:08:08  2024-01-01 03:22:32.500000       1.140000
# 50%           2024-01-01 12:44:45         2024-01-01 12:58:25       2.080000
# 75%           2024-01-01 17:15:06  2024-01-01 17:32:06.500000       4.520000
# max           2024-01-03 22:46:45         2024-01-03 22:53:44      80.850000
# std                           NaN                         NaN       5.277469
#
#         fare_amount
# count  70000.000000
# mean      21.323614
# min     -404.100000
# 25%        8.600000
# 50%       13.500000
# 75%       25.400000
# max      820.000000
# std       22.529081

# %%
# Create machine learning model

def build_model(learning_rate, num_features):
    
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=(num_features,)))
    model.add(keras.layers.Dense(units=1))
    model.compile(optimizer=keras.optimizers.RMSprop(learning_rate=learning_rate),
                  loss="mean_squared_error",
                  metrics=[keras.metrics.RootMeanSquaredError()])
    
    return model

def train_model(model, df, features, label, epochs, batch_size):
    history = model.fit(x=features,
                        y=label,
                        batch_size=batch_size,
                        epochs=epochs)
    
    trained_weight = model.get_weights()[0]
    trained_bias = model.get_weights()[1]

    epochs = history.epoch

    hist = pd.DataFrame(history.history)

    rmse = hist["root_mean_squared_error"]

    return trained_weight, trained_bias, epochs, rmse

def run(df, feature_names, label_name, learning_rate, epochs, batch_size):
    num_features = len(feature_names)
    features = df.loc[:, feature_names].values
    label = df[label_name].values

    model = build_model(learning_rate, num_features)
    model_output = train_model(model, df, features, label, epochs, batch_size)

    return model

# %%
# Generate a correlation matrix to determine fields with greatest correlation to fare amount
print(df.corr(numeric_only=True))

# From this, we see that trip_distance, toll_amount and tip_amount have the greatest influence on fare amount
# Out:
#                        VendorID  passenger_count  trip_distance  RatecodeID  \
# VendorID               1.000000         0.075500       0.041811   -0.076264
# passenger_count        0.075500         1.000000       0.046219   -0.015674
# trip_distance          0.041811         0.046219       1.000000    0.081495
# RatecodeID            -0.076264        -0.015674       0.081495    1.000000
# PULocationID          -0.018388         0.001400      -0.119775   -0.023331
# DOLocationID          -0.019159        -0.008502      -0.075902   -0.009678
# payment_type           0.018626         0.019698      -0.040390   -0.019087
# fare_amount            0.031102         0.060569       0.824931    0.111314
# extra                 -0.611593        -0.060294       0.118988   -0.046627
# mta_tax               -0.063564        -0.022567      -0.047848   -0.049243
# tip_amount             0.031927         0.016859       0.549019    0.008681
# tolls_amount           0.020758         0.048000       0.604632    0.081491
# improvement_surcharge -0.067597        -0.000068       0.017335   -0.002544
# total_amount           0.030953         0.055866       0.833703    0.093596
# congestion_surcharge  -0.045346         0.011191      -0.234943   -0.132889
# Airport_fee            0.040459        -0.002786       0.618913    0.011243
#
#                        PULocationID  DOLocationID  payment_type  fare_amount  \
# VendorID                  -0.018388     -0.019159      0.018626     0.031102
# passenger_count            0.001400     -0.008502      0.019698     0.060569
# trip_distance             -0.119775     -0.075902     -0.040390     0.824931
# RatecodeID                -0.023331     -0.009678     -0.019087     0.111314
# PULocationID               1.000000      0.076400     -0.009588    -0.100321
# DOLocationID               0.076400      1.000000     -0.026081    -0.061179
# payment_type              -0.009588     -0.026081      1.000000    -0.133712
# fare_amount               -0.100321     -0.061179     -0.133712     1.000000
# extra                     -0.048143      0.002394     -0.102550     0.103425
# mta_tax                    0.011969      0.032772     -0.399857     0.042095
# tip_amount                -0.071267     -0.030627     -0.381244     0.564182
# tolls_amount              -0.062128     -0.054900     -0.056758     0.604262
# improvement_surcharge      0.008640      0.009340     -0.458054     0.252505
# total_amount              -0.102876     -0.058419     -0.201741     0.982422
# congestion_surcharge       0.094800      0.096016     -0.320560    -0.136407
# Airport_fee               -0.147245     -0.027368     -0.057814     0.539541
#
#                           extra   mta_tax  tip_amount  tolls_amount  \
# VendorID              -0.611593 -0.063564    0.031927      0.020758
# passenger_count       -0.060294 -0.022567    0.016859      0.048000
# trip_distance          0.118988 -0.047848    0.549019      0.604632
# RatecodeID            -0.046627 -0.049243    0.008681      0.081491
# PULocationID          -0.048143  0.011969   -0.071267     -0.062128
# DOLocationID           0.002394  0.032772   -0.030627     -0.054900
# payment_type          -0.102550 -0.399857   -0.381244     -0.056758
# fare_amount            0.103425  0.042095    0.564182      0.604262
# extra                  1.000000  0.167748    0.136355      0.176687
# mta_tax                0.167748  1.000000    0.006264     -0.101560
# tip_amount             0.136355  0.006264    1.000000      0.415980
# tolls_amount           0.176687 -0.101560    0.415980      1.000000
# improvement_surcharge  0.147348  0.866098    0.101633      0.077330
# total_amount           0.168027  0.069087    0.682003      0.671594
# congestion_surcharge   0.044973  0.644060   -0.076524     -0.113992
# Airport_fee            0.324675  0.085541    0.394922      0.398402
#
#                        improvement_surcharge  total_amount  \
# VendorID                           -0.067597      0.030953
# passenger_count                    -0.000068      0.055866
# trip_distance                       0.017335      0.833703
# RatecodeID                         -0.002544      0.093596
# PULocationID                        0.008640     -0.102876
# DOLocationID                        0.009340     -0.058419
# payment_type                       -0.458054     -0.201741
# fare_amount                         0.252505      0.982422
# extra                               0.147348      0.168027
# mta_tax                             0.866098      0.069087
# tip_amount                          0.101633      0.682003
# tolls_amount                        0.077330      0.671594
# improvement_surcharge               1.000000      0.271940
# total_amount                        0.271940      1.000000
# congestion_surcharge                0.589993     -0.100767
# Airport_fee                         0.096732      0.573442
#
#                        congestion_surcharge  Airport_fee
# VendorID                          -0.045346     0.040459
# passenger_count                    0.011191    -0.002786
# trip_distance                     -0.234943     0.618913
# RatecodeID                        -0.132889     0.011243
# PULocationID                       0.094800    -0.147245
# DOLocationID                       0.096016    -0.027368
# payment_type                      -0.320560    -0.057814
# fare_amount                       -0.136407     0.539541
# extra                              0.044973     0.324675
# mta_tax                            0.644060     0.085541
# tip_amount                        -0.076524     0.394922
# tolls_amount                      -0.113992     0.398402
# improvement_surcharge              0.589993     0.096732
# total_amount                      -0.100767     0.573442
# congestion_surcharge               1.000000    -0.319126
# Airport_fee                       -0.319126     1.000000

# %%
# Hence, use these as the features for the model.
training_df = df[['trip_distance', 'tip_amount', 'tolls_amount', 'fare_amount', 'Airport_fee']].copy()

learning_rate = 0.0001
epochs = 100
batch_size = 100

# Specify the feature and the label.
features = ['trip_distance', 'tip_amount', 'tolls_amount', 'Airport_fee']
label = 'fare_amount'

model_1 = run(training_df, features, label, learning_rate, epochs, batch_size)
# Out:
# Epoch 1/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 886.1326 - root_mean_squared_error: 29.7642
# Epoch 2/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 819.7328 - root_mean_squared_error: 28.6295
# Epoch 3/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 902us/step - loss: 796.3590 - root_mean_squared_error: 28.2149
# Epoch 4/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 906us/step - loss: 729.4849 - root_mean_squared_error: 27.0082
# Epoch 5/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - loss: 679.8127 - root_mean_squared_error: 26.0716
# Epoch 6/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 634.3954 - root_mean_squared_error: 25.1828
# Epoch 7/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 903us/step - loss: 597.3792 - root_mean_squared_error: 24.4398
# Epoch 8/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 859us/step - loss: 580.3749 - root_mean_squared_error: 24.0883
# Epoch 9/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 947us/step - loss: 547.2015 - root_mean_squared_error: 23.3849
# Epoch 10/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 917us/step - loss: 499.2582 - root_mean_squared_error: 22.3421
# Epoch 11/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 859us/step - loss: 461.4900 - root_mean_squared_error: 21.4779
# Epoch 12/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 930us/step - loss: 434.7144 - root_mean_squared_error: 20.8493
# Epoch 13/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 937us/step - loss: 434.2733 - root_mean_squared_error: 20.8269
# Epoch 14/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s
100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 819us/step - loss: 134.3245 - root_mean_squared_error: 11.5730
# Epoch 95/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - loss: 141.4301 - root_mean_squared_error: 11.8901
# Epoch 96/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 878us/step - loss: 162.2634 - root_mean_squared_error: 12.6794
# Epoch 97/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - loss: 142.1418 - root_mean_squared_error: 11.9054
# Epoch 98/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 953us/step - loss: 147.3663 - root_mean_squared_error: 12.1346
# Epoch 99/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 891us/step - loss: 143.3846 - root_mean_squared_error: 11.9527
# Epoch 100/100
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 885us/step - loss: 148.8187 - root_mean_squared_error: 12.1886

# %%
results = model_1.predict_on_batch(training_df.loc[:,features].values)
print(results)
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2024-01-01 00:57:55   2024-01-01 01:17:43                1
# 1             1  2024-01-01 00:03:00   2024-01-01 00:09:36                1
# 2             1  2024-01-01 00:17:06   2024-01-01 00:35:01                1
# 3             1  2024-01-01 00:36:38   2024-01-01 00:44:56                1
# 4             1  2024-01-01 00:46:51   2024-01-01 00:52:57                1
# ...         ...                  ...                   ...              ...
# 69995         1  2024-01-01 23:06:03   2024-01-01 23:28:54                1
# 69996         2  2024-01-01 23:51:07   2024-01-01 23:59:24                1
# 69997         2  2024-01-01 23:00:00   2024-01-01 23:17:31                1
# 69998         2  2024-01-01 23:03:21   2024-01-01 23:18:07                1
# 69999         2  2024-01-01 23:09:36   2024-01-01 23:24:43                1
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.72           1                  N           186
# 1               1.80           1                  N           140
# 2               4.70           1                  N           236
# 3               1.40           1                  N            79
# 4               0.80           1                  N           211
# ...              ...         ...                ...           ...
# 69995           5.10           1                  N            68
# 69996           4.44           1                  N           138
# 69997           7.99           1                  N           138
# 69998           7.37           5                  N            75
# 69999           8.51           1                  N           138
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                79             2        17.70    1.0      0.5        0.00
# 1               236             1        10.00    3.5      0.5        3.75
# 2                79             1        23.30    3.5      0.5        3.00
# 3               211             1        10.00    3.5      0.5        2.00
# 4               148             1         7.90    3.5      0.5        3.20
# ...             ...           ...          ...    ...      ...         ...
# 69995           226             1        25.40    3.5      0.5       10.03
# 69996            93             2        19.10    6.0      0.5        0.00
# 69997           151             1        33.10    6.0      0.5       14.79
# 69998            82             1        19.47    0.0      0.5        2.10
# 69999           170             1        33.80    6.0      0.5       10.15
#
#        tolls_amount  improvement_surcharge  total_amount  \
# 0              0.00                    1.0         22.70
# 1              0.00                    1.0         18.75
# 2              0.00                    1.0         31.30
# 3              0.00                    1.0         17.00
# 4              0.00                    1.0         16.10
# ...             ...                    ...           ...
# 69995          0.00                    1.0         40.43
# 69996          0.00                    1.0         28.35
# 69997          6.94                    1.0         64.08
# 69998          6.94                    1.0         30.01
# 69999          6.94                    1.0         62.64
#
#        congestion_surcharge  Airport_fee
# 0                       2.5         0.00
# 1                       2.5         0.00
# 2                       2.5         0.00
# 3                       2.5         0.00
# 4                       2.5         0.00
# ...                     ...          ...
# 69995                   2.5         0.00
# 69996                   0.0         1.75
# 69997                   0.0         1.75
# 69998                   0.0         0.00
# 69999                   2.5         1.75
#
# [70000 rows x 19 columns]
